# %%
import pandas as pd

df = pd.read_csv("cleaned_coffee_dataset.csv")
df.columns
# Out:
# Index(['Unnamed: 0', 'Country of Origin', 'Farm Name', 'Company', 'Altitude',
#        'Region', 'Number of Bags', 'Bag Weight', 'Harvest Year',
#        'Grading Date', 'Variety', 'Status', 'Processing Method', 'Aroma',
#        'Flavor', 'Aftertaste', 'Acidity', 'Body', 'Balance', 'Uniformity',
#        'Overall', 'Total Cup Points', 'Moisture Percentage',
#        'Category One Defects', 'Quakers', 'Color', 'Category Two Defects',
#        'Expiration', 'Certification Body', 'Mill'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0 Country of Origin                 Farm Name  \
# 0           0          Colombia          Finca El Paraiso
# 1           1            Taiwan  Royal Bean Geisha Estate
# 2           2              Laos        OKLAO coffee farms
# 3           3        Costa Rica                 La Cumbre
# 4           4          Colombia           Finca Santuario
#
#                     Company  Altitude                Region  Number of Bags  \
# 0      Coffee Quality Union    1815.0      Let's pay, Cauca               1
# 1  Taiwan Coffee Laboratory    1200.0                    No               1
# 2  Taiwan Coffee Laboratory    1300.0  Laos Borofen Plateau              19
# 3      Coffee Quality Union    1900.0   Los Santos, Tarrazu               1
# 4      Coffee Quality Union    1975.0        Popayan, Cauca               2
#
#   Bag Weight Harvest Year          Grading Date  ... Overall Total Cup Points  \
# ...

# %%
df.Flavor
# Out:
# 0      8.50
# 1      8.50
# 2      8.42
# 3      8.17
# 4      8.33
#        ...
# 202    7.17
# 203    7.08
# 204    7.17
# 205    6.75
# 206    7.08
# Name: Flavor, Length: 207, dtype: float64
